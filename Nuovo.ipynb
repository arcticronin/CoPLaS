# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colormaps, cm

# %matplotlib inline

from sksurv.datasets import load_breast_cancer
from sksurv.linear_model import CoxPHSurvivalAnalysis, CoxnetSurvivalAnalysis
from sksurv.preprocessing import OneHotEncoder

from sklearn import set_config
from sklearn.model_selection import GridSearchCV, KFold
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

set_config(display="text")  # displays text representation of estimators

from pandas.api.types import CategoricalDtype


## 
import warnings
from sklearn.exceptions import FitFailedWarning
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# # Utils

# %%
def plot_coefficients(coefs, n_highlight):
    _, ax = plt.subplots(figsize=(9, 6))
    n_features = coefs.shape[0]
    alphas = coefs.columns
    for row in coefs.itertuples():
        ax.semilogx(alphas, row[1:], ".-", label=row.Index)

    alpha_min = alphas.min()
    # takes most important coeffs in abs value
    top_coefs = coefs.loc[:, alpha_min].map(abs).sort_values().tail(n_highlight)
    for name in top_coefs.index:
        coef = coefs.loc[name, alpha_min]
        plt.text(alpha_min, coef, name + "   ", horizontalalignment="right", verticalalignment="center")

    ax.yaxis.set_label_position("right")
    ax.yaxis.tick_right()
    ax.grid(True)
    ax.set_xlabel("alpha")
    ax.set_ylabel("coefficient")

# %% [markdown]
# # Preprocessing

# %%
data = pd.read_csv("processed/BLCA_data_preprocessed.csv")#, low_memory=False)

# %%
modality_list = ["clinical",
"gex",
"rppa",
"mirna",
"mutation",
"meth",
"cnv"]

# %%
omic = 0 # 0 is clinical
modalities_to_keep = modality_list[omic]
modality_mask = [col for col in data.columns if col.rsplit("_")[0] in modalities_to_keep]

# %%
X = data[modality_mask]
y = data[['OS', 'OS_days']].rename(columns={'OS_days' : 'time'}).rename(columns={'OS' : 'event'})
y['event'] = y['event'].astype(bool)
y['time'] = y['time'].astype(float)
y = np.array(y.to_records(index=False))

# %%
y.dtype
# Out:
# dtype((numpy.record, [('event', '?'), ('time', '<f8')]))

# %%
X.dtypes
# Out:
# clinical_age_at_initial_pathologic_diagnosis      int64
# clinical_gender                                  object
# clinical_race                                    object
# clinical_ajcc_pathologic_tumor_stage             object
# clinical_clinical_stage                         float64
# clinical_histological_type                       object
# dtype: object

# %%
# transform objects into categories
for col in X.columns:
    if X[col].dtype == 'object':
        X.loc[:, col] = X[col].astype('category')

# %% [markdown]
# # Ridge - L2 Models to estabilish ranking

# %%
alphas = 10.0 ** np.linspace(-4, 4, 50)
coefficients = {}

cph = CoxPHSurvivalAnalysis()
for alpha in alphas:
    cph.set_params(alpha=alpha)
    cph.fit(Xt, y)
    key = round(alpha, 5)
    coefficients[key] = cph.coef_

coefficients = pd.DataFrame.from_dict(coefficients).rename_axis(index="feature", columns="alpha").set_index(Xt.columns)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 7
#       5 for alpha in alphas:
#       6     cph.set_params(alpha=alpha)
# ----> 7     cph.fit(Xt, y)
#       8     key = round(alpha, 5)
#       9     coefficients[key] = cph.coef_
#
# NameError: name 'Xt' is not defined

# %%
plot_coefficients(coefficients, n_highlight=5)

# %%
coefficients
# Out:
# alpha                                           0.00010      0.00015      \
# clinical_age_at_initial_pathologic_diagnosis       0.031822     0.031822
# clinical_gender=MALE                              -0.051096    -0.051097
# clinical_race=BLACK OR AFRICAN AMERICAN            0.652100     0.652097
# clinical_race=WHITE                                0.139221     0.139220
# clinical_ajcc_pathologic_tumor_stage=Stage II      0.097148     0.097074
# clinical_ajcc_pathologic_tumor_stage=Stage III     0.448284     0.448210
# clinical_ajcc_pathologic_tumor_stage=Stage IV      1.065002     1.064928
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           0.00021      0.00031      \
# clinical_age_at_initial_pathologic_diagnosis       0.031822     0.031822
# clinical_gender=MALE                              -0.051098    -0.051099
# clinical_race=BLACK OR AFRICAN AMERICAN            0.652093     0.652087
# clinical_race=WHITE                                0.139219     0.139218
# clinical_ajcc_pathologic_tumor_stage=Stage II      0.096967     0.096812
# clinical_ajcc_pathologic_tumor_stage=Stage III     0.448103     0.447947
# clinical_ajcc_pathologic_tumor_stage=Stage IV      1.064820     1.064663
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           0.00045      0.00066      \
# clinical_age_at_initial_pathologic_diagnosis       0.031822     0.031822
# clinical_gender=MALE                              -0.051101    -0.051103
# clinical_race=BLACK OR AFRICAN AMERICAN            0.652078     0.652065
# clinical_race=WHITE                                0.139215     0.139212
# clinical_ajcc_pathologic_tumor_stage=Stage II      0.096585     0.096255
# clinical_ajcc_pathologic_tumor_stage=Stage III     0.447720     0.447389
# clinical_ajcc_pathologic_tumor_stage=Stage IV      1.064435     1.064103
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           0.00095      0.00139      \
# clinical_age_at_initial_pathologic_diagnosis       0.031822     0.031822
# clinical_gender=MALE                              -0.051107    -0.051113
# clinical_race=BLACK OR AFRICAN AMERICAN            0.652046     0.652019
# clinical_race=WHITE                                0.139208     0.139201
# clinical_ajcc_pathologic_tumor_stage=Stage II      0.095776     0.095080
# clinical_ajcc_pathologic_tumor_stage=Stage III     0.446909     0.446212
# clinical_ajcc_pathologic_tumor_stage=Stage IV      1.063621     1.062921
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           0.00202      0.00295      ...  \
# clinical_age_at_initial_pathologic_diagnosis       0.031822     0.031822  ...
# clinical_gender=MALE                              -0.051121    -0.051133  ...
# clinical_race=BLACK OR AFRICAN AMERICAN            0.651979     0.651920  ...
# clinical_race=WHITE                                0.139191     0.139176  ...
# clinical_ajcc_pathologic_tumor_stage=Stage II      0.094071     0.092610  ...
# clinical_ajcc_pathologic_tumor_stage=Stage III     0.445200     0.443736  ...
# clinical_ajcc_pathologic_tumor_stage=Stage IV      1.061906     1.060435  ...
# clinical_clinical_stage                            0.000000     0.000000  ...
#
# alpha                                           339.32218    494.17134    \
# clinical_age_at_initial_pathologic_diagnosis       0.032498     0.032224
# clinical_gender=MALE                              -0.003161    -0.002203
# clinical_race=BLACK OR AFRICAN AMERICAN            0.012736     0.008762
# clinical_race=WHITE                                0.001413     0.001167
# clinical_ajcc_pathologic_tumor_stage=Stage II     -0.047395    -0.033829
# clinical_ajcc_pathologic_tumor_stage=Stage III    -0.019003    -0.013652
# clinical_ajcc_pathologic_tumor_stage=Stage IV      0.069325     0.049495
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           719.68567    1048.11313   \
# clinical_age_at_initial_pathologic_diagnosis       0.031774     0.031098
# clinical_gender=MALE                              -0.001530    -0.001060
# clinical_race=BLACK OR AFRICAN AMERICAN            0.006014     0.004119
# clinical_race=WHITE                                0.000921     0.000709
# clinical_ajcc_pathologic_tumor_stage=Stage II     -0.023899    -0.016764
# clinical_ajcc_pathologic_tumor_stage=Stage III    -0.009659    -0.006758
# clinical_ajcc_pathologic_tumor_stage=Stage IV      0.034943     0.024475
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           1526.41797   2222.99648   \
# clinical_age_at_initial_pathologic_diagnosis       0.030139     0.028830
# clinical_gender=MALE                              -0.000735    -0.000509
# clinical_race=BLACK OR AFRICAN AMERICAN            0.002816     0.001920
# clinical_race=WHITE                                0.000540     0.000412
# clinical_ajcc_pathologic_tumor_stage=Stage II     -0.011706    -0.008152
# clinical_ajcc_pathologic_tumor_stage=Stage III    -0.004688    -0.003229
# clinical_ajcc_pathologic_tumor_stage=Stage IV      0.017048     0.011832
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           3237.45754   4714.86636   \
# clinical_age_at_initial_pathologic_diagnosis       0.027113     0.024957
# clinical_gender=MALE                              -0.000354    -0.000247
# clinical_race=BLACK OR AFRICAN AMERICAN            0.001306     0.000886
# clinical_race=WHITE                                0.000315     0.000244
# clinical_ajcc_pathologic_tumor_stage=Stage II     -0.005670    -0.003943
# clinical_ajcc_pathologic_tumor_stage=Stage III    -0.002212    -0.001508
# clinical_ajcc_pathologic_tumor_stage=Stage IV      0.008192     0.005663
# clinical_clinical_stage                            0.000000     0.000000
#
# alpha                                           6866.48845   10000.00000
# clinical_age_at_initial_pathologic_diagnosis       0.022382     0.019477
# clinical_gender=MALE                              -0.000172    -0.000121
# clinical_race=BLACK OR AFRICAN AMERICAN            0.000600     0.000405
# clinical_race=WHITE                                0.000189     0.000147
# clinical_ajcc_pathologic_tumor_stage=Stage II     -0.002742    -0.001908
# clinical_ajcc_pathologic_tumor_stage=Stage III    -0.001024    -0.000693
# clinical_ajcc_pathologic_tumor_stage=Stage IV      0.003912     0.002701
# clinical_clinical_stage                            0.000000     0.000000
#
# [8 rows x 50 columns]

# %% [markdown]
# # Lasso - Study coefficients behaviour changing alpha

# %%
cox_lasso = CoxnetSurvivalAnalysis(l1_ratio=1.0, alpha_min_ratio=0.01, verbose=True)
cox_lasso.fit(Xt, y)
# Out:
# CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=1.0, verbose=True)

# %%
cox_lasso.get_params()
# Out:
# {'alpha_min_ratio': 0.01,
#  'alphas': None,
#  'copy_X': True,
#  'fit_baseline_model': False,
#  'l1_ratio': 1.0,
#  'max_iter': 100000,
#  'n_alphas': 100,
#  'normalize': False,
#  'penalty_factor': None,
#  'tol': 1e-07,
#  'verbose': True}

# %%
coefficients_lasso = pd.DataFrame(cox_lasso.coef_, index=Xt.columns, columns=np.round(cox_lasso.alphas_, 5))

plot_coefficients(coefficients_lasso, n_highlight=4)

# %% [markdown]
# # Elastic-Net - a caso

# %%
cox_elastic_net = CoxnetSurvivalAnalysis(l1_ratio=0.9, alpha_min_ratio=0.01)
cox_elastic_net.fit(Xt, y)
# Out:
# CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=0.9)

# %%
coefficients_elastic_net = pd.DataFrame(
    cox_elastic_net.coef_, index=Xt.columns, columns=np.round(cox_elastic_net.alphas_, 5)
)

plot_coefficients(coefficients_elastic_net, n_highlight=4)

# %% [markdown]
# # Omic score

# %%
coxnet_pipe = make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.9, alpha_min_ratio=0.01, max_iter=100))
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FitFailedWarning)
coxnet_pipe.fit(Xt, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('coxnetsurvivalanalysis',
#                  CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=0.9,
#                                         max_iter=100))])

# %%
estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
cv = KFold(n_splits=5, shuffle=True, random_state=42)
gcv = GridSearchCV(
    make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.001)),
    param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
    cv=cv,
    error_score=0.5,
    n_jobs=1,
).fit(Xt, y)

cv_results = pd.DataFrame(gcv.cv_results_)

# %%
alphas = cv_results.param_coxnetsurvivalanalysis__alphas.map(lambda x: x[0])
mean = cv_results.mean_test_score
std = cv_results.std_test_score

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(alphas, mean)
ax.fill_between(alphas, mean - std, mean + std, alpha=0.15)
ax.set_xscale("log")
ax.set_ylabel("concordance index")
ax.set_xlabel("alpha")
ax.axvline(gcv.best_params_["coxnetsurvivalanalysis__alphas"][0], c="C1")
ax.axhline(0.5, color="grey", linestyle="--")
ax.grid(True)

# %%
best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
best_coefs = pd.DataFrame(best_model.coef_, index=Xt.columns, columns=["coefficient"])

non_zero = np.sum(best_coefs.iloc[:, 0] != 0)
print(f"Number of non-zero coefficients: {non_zero}")

non_zero_coefs = best_coefs.query("coefficient != 0")
coef_order = non_zero_coefs.abs().sort_values("coefficient").index

_, ax = plt.subplots(figsize=(6, 8))
non_zero_coefs.loc[coef_order].plot.barh(ax=ax, legend=False)
ax.set_xlabel("coefficient")
ax.grid(True)
# Out:
# Number of non-zero coefficients: 7

# %%
# score -> surrogate for knowledge-based priority order
np.absolute(best_coefs["coefficient"].to_numpy()).mean()
# Out:
# 0.11825913457491835

# %% [markdown]
# # Best Alphas

# %% [markdown]
# Before we can use GridSearchCV, we need to determine the set of alphas which we want to evaluate. To do this, we fit a penalized Cox model to the whole data and retrieve the estimated set of alphas.
# Since, we are only interested in alphas and not the coefficients, we can use only a few iterations for improved speed.
# Note that we are using StandardScaler to account for scale differences among features and allow direct comparison of coefficients.

# %%
coxnet_pipe = make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.9, alpha_min_ratio=0.01, max_iter=100))
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FitFailedWarning)
coxnet_pipe.fit(Xt, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('coxnetsurvivalanalysis',
#                  CoxnetSurvivalAnalysis(alpha_min_ratio=0.01, l1_ratio=0.9,
#                                         max_iter=100))])

# %%
estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
cv = KFold(n_splits=5, shuffle=True, random_state=42)
gcv = GridSearchCV(
    make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.9)),
    param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
    cv=cv,
    error_score=0.5,
    n_jobs=1,
).fit(Xt, y)

cv_results = pd.DataFrame(gcv.cv_results_)

# %%
alphas = cv_results.param_coxnetsurvivalanalysis__alphas.map(lambda x: x[0])
mean = cv_results.mean_test_score
std = cv_results.std_test_score

fig, ax = plt.subplots(figsize=(9, 6))
ax.plot(alphas, mean)
ax.fill_between(alphas, mean - std, mean + std, alpha=0.15)
ax.set_xscale("log")
ax.set_ylabel("concordance index")
ax.set_xlabel("alpha")
ax.axvline(gcv.best_params_["coxnetsurvivalanalysis__alphas"][0], c="C1")
ax.axhline(0.5, color="grey", linestyle="--")
ax.grid(True)

# %%
best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
best_coefs = pd.DataFrame(best_model.coef_, index=Xt.columns, columns=["coefficient"])

non_zero = np.sum(best_coefs.iloc[:, 0] != 0)
print(f"Number of non-zero coefficients: {non_zero}")

non_zero_coefs = best_coefs.query("coefficient != 0")
coef_order = non_zero_coefs.abs().sort_values("coefficient").index

_, ax = plt.subplots(figsize=(6, 8))
non_zero_coefs.loc[coef_order].plot.barh(ax=ax, legend=False)
ax.set_xlabel("coefficient")
ax.grid(True)
# Out:
# Number of non-zero coefficients: 6

# %%
coxnet_pred = make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.9, fit_baseline_model=True))
coxnet_pred.set_params(**gcv.best_params_)
coxnet_pred.fit(Xt, y)
# Out:
# Pipeline(steps=[('standardscaler', StandardScaler()),
#                 ('coxnetsurvivalanalysis',
#                  CoxnetSurvivalAnalysis(alphas=[0.005525453596631809],
#                                         fit_baseline_model=True,
#                                         l1_ratio=0.9))])

# %%
Xt.loc[:, "clinical_ajcc_pathologic_tumor_stage=Stage IV"].astype(int)
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 325    0
# 326    0
# 327    0
# 328    0
# 329    1
# Name: clinical_ajcc_pathologic_tumor_stage=Stage IV, Length: 330, dtype: int64

# %%
surv_fns = coxnet_pred.predict_survival_function(Xt)

time_points = np.quantile(y["time"], np.linspace(0, 0.6, 100))
legend_handles = []
legend_labels = []
_, ax = plt.subplots(figsize=(9, 6))
for fn, label in zip(surv_fns, (-Xt.loc[:, "clinical_ajcc_pathologic_tumor_stage=Stage IV"].astype(int).astype(bool)).astype(int)):
    (line,) = ax.step(time_points, fn(time_points), where="post", color=f"C{label}", alpha=0.5)
    if len(legend_handles) <= label: 
        print("label = ", label)
        print("len = ", len(legend_handles))
        name =  "Another stage" if label == 1 else "Stage IV"
        legend_labels.append(name)
        legend_handles.append(line)

ax.legend(legend_handles, legend_labels)
ax.set_xlabel("time")
ax.set_ylabel("Survival probability")
ax.grid(True)
# Out:
# label =  0
# len =  0
# label =  1
# len =  1

# %%
plot_coefficients(coefficients, n_highlight=5)

# %%
(-Xt.loc[:, "clinical_ajcc_pathologic_tumor_stage=Stage IV"].astype(int).astype(bool)).astype(int)
# Out:
# 0      0
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 325    1
# 326    1
# 327    1
# 328    1
# 329    0
# Name: clinical_ajcc_pathologic_tumor_stage=Stage IV, Length: 330, dtype: int64

# %%
surv_fns = coxnet_pred.predict_survival_function(Xt)

time_points = np.quantile(y["time"], np.linspace(0, 0.6, 100))
legend_handles = []
legend_labels = []
_, ax = plt.subplots(figsize=(9, 6))
for fn, label in zip(surv_fns, Xt.loc[:, "clinical_ajcc_pathologic_tumor_stage=Stage II"].astype(int)):
    (line,) = ax.step(time_points, fn(time_points), where="post", color=f"C{label}", alpha=0.5)
    if len(legend_handles) <= label:
        print("label = ", label)
        print("len = ", len(legend_handles))
        name = "Stage II" if label == 1 else "Another stage"
        legend_labels.append(name)
        legend_handles.append(line)

ax.legend(legend_handles, legend_labels)
ax.set_xlabel("time")
ax.set_ylabel("Survival probability")
ax.grid(True)
# Out:
# label =  0
# len =  0
# label =  1
# len =  1

# %%
min_value = Xt.loc[:, "clinical_age_at_initial_pathologic_diagnosis"].min()
max_value = Xt.loc[:, "clinical_age_at_initial_pathologic_diagnosis"].max()

surv_fns = coxnet_pred.predict_survival_function(Xt)

time_points = np.quantile(y["time"], np.linspace(0, 0.6, 100))
legend_handles = []
legend_labels = []
fig, ax = plt.subplots(figsize=(9, 6))
cmap = colormaps['viridis']
for fn, label in zip(surv_fns, Xt.loc[:, "clinical_age_at_initial_pathologic_diagnosis"].astype(int)):
    normalized_color = (label - min_value) / (max_value - min_value)
    (line,) = ax.step(time_points, fn(time_points), where="post", color = cmap(normalized_color), alpha=0.5)
    if len(legend_handles) <= label and ((label >= max_value - 2 ) or (label <= min_value + 5)):
        name = label
        legend_labels.append(name)
        legend_handles.append(line)

norm = plt.Normalize(vmin=min_value, vmax=max_value)  # Normalize the data range to [0, 1]
cbar = plt.colorbar(cm.ScalarMappable(norm=norm, cmap=cmap), ax=ax)

#ax.legend(legend_handles, legend_labels)
ax.set_xlabel("time")
ax.set_ylabel("Survival probability")
ax.set_title("Survival function by age")
ax.grid(True)

# %%
plot_coefficients(coefficients, n_highlight=5)

# %% [markdown]
# # Crossval

# %%
# Initialize the 5-fold cross-validator
kf = KFold(n_splits=5, shuffle=True, random_state=42)
coefficients_df = pd.DataFrame()
alphas = []

## alpha -> best alpha on average -> refit best alpha each fold and take coefficients
## mean mean absolute error  of non-censored !!!!!!!

for i, (train_index, test_index) in enumerate(kf.split(Xt)):
    X_train = Xt.iloc[train_index]
    X_test = Xt.iloc[test_index]
    y_train = y[train_index]
    y_test = y[test_index]
    
    coxnet_pipe = make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.9, alpha_min_ratio=0.01, max_iter=100))
    warnings.simplefilter("ignore", UserWarning)
    warnings.simplefilter("ignore", FitFailedWarning)
    coxnet_pipe.fit(X_train, y_train)
    estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
    cv = KFold(n_splits=5, shuffle=True, random_state=42)
    gcv = GridSearchCV(
        make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.9)),
        param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
        cv=cv,
        error_score=0.5,
        n_jobs=1,
    ).fit(X_train, y_train)

    #cv_results = pd.DataFrame(gcv.cv_results_)
    best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
    best_coefs = pd.DataFrame(best_model.coef_, index=X_train.columns, columns=["coefficient"])
    
    alphas.append(best_model)
    
    if coefficients_df.empty:
        coefficients_df = best_coefs
        coefficients_df.rename(columns={'coefficient': 'coeff_0'}, inplace=True)
    else:
        coefficients_df[f"coeff_{i}"] = best_coefs

# Convert the list of coefficients into a DataFrame for easy visualization
#coefficients_df = pd.DataFrame(coefficients_list)
#print(coefficients_df)

# %%
alphas
# Out:
# [CoxnetSurvivalAnalysis(alphas=[0.032523181328471006], l1_ratio=0.9),
#  CoxnetSurvivalAnalysis(alphas=[0.033687290890104186], l1_ratio=0.9),
#  CoxnetSurvivalAnalysis(alphas=[0.011682559531290567], l1_ratio=0.9),
#  CoxnetSurvivalAnalysis(alphas=[0.0044305055163304475], l1_ratio=0.9),
#  CoxnetSurvivalAnalysis(alphas=[0.059002035865625704], l1_ratio=0.9)]

# %%
coefficients_df
# Out:
#                                                  coeff_0   coeff_1   coeff_2  \
# clinical_age_at_initial_pathologic_diagnosis    0.326246  0.172202  0.264646
# clinical_gender=MALE                           -0.002361  0.000000  0.000000
# clinical_race=BLACK OR AFRICAN AMERICAN         0.076431  0.094310  0.150527
# clinical_race=WHITE                             0.000000  0.000000  0.055207
# clinical_ajcc_pathologic_tumor_stage=Stage II  -0.115129 -0.080409 -0.168873
# clinical_ajcc_pathologic_tumor_stage=Stage III  0.000000  0.000000  0.000000
# clinical_ajcc_pathologic_tumor_stage=Stage IV   0.259999  0.208705  0.245839
# clinical_clinical_stage                         0.000000  0.000000  0.000000
#
#                                                  coeff_3   coeff_4
# clinical_age_at_initial_pathologic_diagnosis    0.377796  0.203760
# clinical_gender=MALE                            0.051169  0.000000
# clinical_race=BLACK OR AFRICAN AMERICAN         0.147822  0.000000
# clinical_race=WHITE                             0.046936  0.000000
# clinical_ajcc_pathologic_tumor_stage=Stage II   0.000000 -0.061347
# clinical_ajcc_pathologic_tumor_stage=Stage III  0.096564  0.000000
# clinical_ajcc_pathologic_tumor_stage=Stage IV   0.417860  0.313186
# clinical_clinical_stage                         0.000000  0.000000

# %%
coefficents_cv = pd.DataFrame(coefficients_df.mean(axis=1))
coefficents_cv.rename(columns={ 0 : 'coeff_CV'}, inplace=True)
coefficents_cv
# Out:
#                                                 coeff_CV
# clinical_age_at_initial_pathologic_diagnosis    0.268930
# clinical_gender=MALE                            0.009762
# clinical_race=BLACK OR AFRICAN AMERICAN         0.093818
# clinical_race=WHITE                             0.020429
# clinical_ajcc_pathologic_tumor_stage=Stage II  -0.085152
# clinical_ajcc_pathologic_tumor_stage=Stage III  0.019313
# clinical_ajcc_pathologic_tumor_stage=Stage IV   0.289118
# clinical_clinical_stage                         0.000000

# %% [markdown]
# # get residual

# %%
coefficents_cv['coeff_CV'].to_dict()
# Out:
# {'clinical_age_at_initial_pathologic_diagnosis': 0.26893032980991455,
#  'clinical_gender=MALE': 0.009761737947847439,
#  'clinical_race=BLACK OR AFRICAN AMERICAN': 0.09381811256464363,
#  'clinical_race=WHITE': 0.020428602586989243,
#  'clinical_ajcc_pathologic_tumor_stage=Stage II': -0.08515167933527454,
#  'clinical_ajcc_pathologic_tumor_stage=Stage III': 0.019312794061825855,
#  'clinical_ajcc_pathologic_tumor_stage=Stage IV': 0.2891178793907106,
#  'clinical_clinical_stage': 0.0}

# %%
coxnet_pipe = make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=0.9, alpha_min_ratio=0.01, max_iter=100))
warnings.simplefilter("ignore", UserWarning)
warnings.simplefilter("ignore", FitFailedWarning)
coxnet_pipe.fit(Xt, y)
estimated_alphas = coxnet_pipe.named_steps["coxnetsurvivalanalysis"].alphas_
cv = KFold(n_splits=5, shuffle=True, random_state=42)
gcv = GridSearchCV(
    make_pipeline(StandardScaler(), CoxnetSurvivalAnalysis(l1_ratio=1)),
    param_grid={"coxnetsurvivalanalysis__alphas": [[v] for v in estimated_alphas]},
    cv=cv,
    error_score=0.5,
    n_jobs=1,
).fit(Xt, y)

# %%
best_model = gcv.best_estimator_.named_steps["coxnetsurvivalanalysis"]
best_coefs = pd.DataFrame(best_model.coef_, index=Xt.columns, columns=["coefficient"])

# %%
best_model.coef_
# Out:
# array([[ 0.32145068],
#        [-0.01047596],
#        [ 0.12678079],
#        [ 0.02583571],
#        [-0.14439684],
#        [ 0.        ],
#        [ 0.29292695],
#        [ 0.        ]])

# %%
best_model.coef_ = coefficents_cv.to_numpy()
best_model.coef_
# Out:
# array([[ 0.26893033],
#        [ 0.00976174],
#        [ 0.09381811],
#        [ 0.0204286 ],
#        [-0.08515168],
#        [ 0.01931279],
#        [ 0.28911788],
#        [ 0.        ]])

# %%
best_model.predict(Xt)[:10]
# Out:
# array([17.79977966, 16.7142966 , 21.28523745, 19.14355655, 16.08085845,
#        18.87462622, 18.49146968, 15.1096016 , 17.7989049 , 17.79977966])

# %%
y.dtype
# Out:
# dtype((numpy.record, [('event', '?'), ('time', '<i8')]))

# %%
# convert time to to floating point
y2 = np.empty(
    y.shape,
    dtype=np.dtype((np.record, [('event', '?'), ('time', '<f8')])))

y2['event'] = y['event']
y2['time'] = (y['time'].astype('<f8'))-(best_model.predict(Xt))

# %%
y2[:4]
# Out:
# array([(False,  300.20022034), (False, 1581.2857034 ),
#        ( True,  171.71476255), ( True,  510.85644345)],
#       dtype=(numpy.record, [('event', '?'), ('time', '<f8')]))
